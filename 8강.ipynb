# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.title("T-Express")
AN = (735,745,750,750,745,735,720,700,670,630,
      580,520,450,360,270,200,140,110,85,60,50,
      45,40,35,35,40,45,50,60,90,120,
      150,200,300,500,630,700,750,800,830,
      850,870,880,890,895,900)
T = pd.DataFrame(AN)
plt.plot(T, color="olive", label="Maximum angle 77˚")
plt.legend(loc="upper center")

# %% [markdown]
# ## 티익스프레스 레일 그래프로 그려보기
# - 각도를 계산하고 곡선 부분을 잘 다듬어서 최대각도 77도를 표현해봤다.
