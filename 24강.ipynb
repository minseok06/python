# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('data/nba.csv')
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# 열의 마지막 5개의 개수를 보여준다
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
df.shape
# 열과 행의 개수를 보여준다
# Out:
# (458, 9)

# %% [markdown]
# # 성대가 알려준 단수

# %%
df.dtypes
# 데이터 타입을 알려준다
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
df[['Salary','Team','Name']].tail()
# Out:
#         Salary       Team          Name
# 453  2433333.0  Utah Jazz  Shelvin Mack
# 454   900000.0  Utah Jazz     Raul Neto
# 455  2900000.0  Utah Jazz  Tibor Pleiss
# 456   947276.0  Utah Jazz   Jeff Withey
# 457        NaN        NaN           NaN

# %%
df['Weight in Kilograms'] = df['Weight'] * 0.453592
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Weight in Kilograms
# 0              Texas  7730337.0            81.646560
# 1          Marquette  6796117.0           106.594120
# 2  Boston University        NaN            92.986360
# 3      Georgia State  1148640.0            83.914520
# 4                NaN  5000000.0           104.779752

# %%
df['Salary in Millions'] = df['Salary'] / 1000000
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Weight in Kilograms  Salary in Millions
# 0              Texas  7730337.0            81.646560            7.730337
# 1          Marquette  6796117.0           106.594120            6.796117
# 2  Boston University        NaN            92.986360                 NaN
# 3      Georgia State  1148640.0            83.914520            1.148640
# 4                NaN  5000000.0           104.779752            5.000000

# %%
df.dropna().tail(10)
# Out:
#                Name       Team  Number Position   Age Height  Weight  \
# 442   Trevor Booker  Utah Jazz    33.0       PF  28.0    6-8   228.0
# 443      Trey Burke  Utah Jazz     3.0       PG  23.0    6-1   191.0
# 444      Alec Burks  Utah Jazz    10.0       SG  24.0    6-6   214.0
# 446  Derrick Favors  Utah Jazz    15.0       PF  24.0   6-10   265.0
# 448  Gordon Hayward  Utah Jazz    20.0       SF  26.0    6-8   226.0
# 449     Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451   Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453    Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456     Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0
#
#           College      Salary  Weight in Kilograms  Salary in Millions
# 442       Clemson   4775000.0           103.418976            4.775000
# ...

# %%
df.dropna(how = "all", inplace = True)

# %% [markdown]
# # 이 두개의 차이가 뭘까

# %%
df.dropna(inplace = True)

# %%
df.replace({None},{0}).head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#          College     Salary  Weight in Kilograms  Salary in Millions
# 0          Texas  7730337.0            81.646560            7.730337
# 1      Marquette  6796117.0           106.594120            6.796117
# 3  Georgia State  1148640.0            83.914520            1.148640
# 6            LSU  1170960.0           106.594120            1.170960
# 7        Gonzaga  2165160.0           107.954896            2.165160

# %%
df.fillna(0)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  Weight in Kilograms  Salary in Millions
# ...

# %%
df['Salary'].fillna(0).head(10)
# Out:
# 0     7730337.0
# 1     6796117.0
# 3     1148640.0
# 6     1170960.0
# 7     2165160.0
# 8     1824360.0
# 9     3431040.0
# 10    2569260.0
# 11    6912869.0
# 12    3425510.0
# Name: Salary, dtype: float64

# %%
df = pd.read_csv('data/nba.csv')
df['Salary'] = df['Salary'].fillna(0)
df.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         0.0
# 3      Georgia State   1148640.0
# ...

# %%
df['College'] = df['College'].replace([None],['None'])
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df['College'].fillna('None', inplace=True)
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df = pd.read_csv('data/nba.csv')

# %%
df.dropna(how='any')
df['Salary'] = df['Salary'].fillna(0)
df['College'].fillna('None', inplace=True)
df.head(6)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         0.0
# 3      Georgia State   1148640.0
# 4               None   5000000.0
# 5               None  12000000.0

# %%
name = input('넌 이름이 뭐야? : ')
print('안녕 {}아 만나서 반가워'.format(name[1:]))
print('내 이름은 재마이야!')
# Out:
# 넌 이름이 뭐야? :
# 안녕 아 만나서 반가워
# 내 이름은 재마이야!

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df['Salary'] = df['Salary'].astype('int')
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
df.dropna(how='all', inplace=True)
df['Salary'] = df['Salary'].fillna(0)
df['Salary'] = df['Salary'].astype('int')
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College   Salary
# 0                Texas  7730337
# ...

# %%
nba = pd.read_csv('data/nba.csv')

# %%
nba.sort_values(by=['Salary'], ascending=False).head(10)
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 109        Kobe Bryant     Los Angeles Lakers    24.0       SF  37.0    6-6
# 169       LeBron James    Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33     Carmelo Anthony        New York Knicks     7.0       SF  32.0    6-8
# 251      Dwight Howard        Houston Rockets    12.0        C  30.0   6-11
# 339         Chris Bosh             Miami Heat     1.0       PF  32.0   6-11
# 100         Chris Paul   Los Angeles Clippers     3.0       PG  31.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
# 164       Derrick Rose          Chicago Bulls     1.0       PG  27.0    6-3
# 349        Dwyane Wade             Miami Heat     3.0       SG  34.0    6-4
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0   6-11
#
#      Weight       College      Salary
# 109   212.0           NaN  25000000.0
# 169   250.0           NaN  22970500.0
# ...

# %%
nba.sort_values(by=['Number'], ascending=False).head(5)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 1        Jae Crowder          Boston Celtics    99.0       SF  25.0    6-6
# 68    Lucas Nogueira         Toronto Raptors    92.0        C  23.0    7-0
# 5       Amir Johnson          Boston Celtics    90.0       PF  29.0    6-9
# 372      Drew Gooden      Washington Wizards    90.0       PF  34.0   6-10
# 398  Nemanja Bjelica  Minnesota Timberwolves    88.0       PF  28.0   6-10
#
#      Weight    College      Salary
# 1     235.0  Marquette   6796117.0
# 68    220.0        NaN   1842000.0
# 5     240.0        NaN  12000000.0
# 372   250.0     Kansas   3300000.0
# 398   240.0        NaN   3950001.0

# %%
nba.sort_values('Salary', ascending=False, na_position='first').tail()
# Out:
#                        Name                  Team  Number Position   Age  \
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0
# 135           Alan Williams          Phoenix Suns    15.0        C  23.0
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0
# 130            Phil Pressey          Phoenix Suns    25.0       PG  25.0
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF  23.0
#
#     Height  Weight           College    Salary
# 175    6-5   179.0         Tennessee  111196.0
# 135    6-8   260.0  UC Santa Barbara   83397.0
# 291    6-5   220.0  UC Santa Barbara   55722.0
# 130   5-11   175.0          Missouri   55722.0
# 32     6-7   205.0               NaN   30888.0

# %%
nba = pd.read_csv('data/nba.csv').dropna(how='all')
nba['Salary'] = nba['Salary'].fillna(0).astype('int')
# 연봉 순위 구하기
nba['Salary Rank'] = nba['Salary'].rank(ascending = False).astype('int')
nba.sort_values(by = 'Salary', ascending = False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 353    Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 264    Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 273   Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
#
#      Weight       College    Salary  Salary Rank
# ...

# %% [markdown]
# # 적극적으로 해결해 낼 수 있다는 자신감을 갖자!

# %%
df = pd.read_csv('data/employees.csv')
df.head(10)
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# ...

# %%
df.dtypes
# Out:
# First Name            object
# Gender                object
# Start Date            object
# Last Login Time       object
# Salary                 int64
# Bonus %              float64
# Senior Management     object
# Team                  object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df['Gender'] = df['Gender'].astype('category')
df[['Last Login Time','Start Date']] = df[['Last Login Time','Start Date']].astype('datetime64')
df['Senior Management'] = df['Senior Management'].astype('bool')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
df = pd.read_csv('data/employees.csv', parse_dates = ['Start Date','Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
df = df[df['Gender']=='Male']
df = df[df['Team']=='Marketing']

df.head(10)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2023-11-14 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2023-11-14 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2023-11-14 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2023-11-14 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2023-11-14 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2023-11-14 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2023-11-14 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2023-11-14 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2023-11-14 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2023-11-14 20:59:00  135490   19.934
#
#      Senior Management       Team
# 0                 True  Marketing
# 21               False  Marketing
# 26                True  Marketing
# 74               False  Marketing
# ...

# %% [markdown]
# # 기존의 변수를 건드리지 않고 새로운 변수로 만든다

# %%
df = pd.read_csv('data/employees.csv', parse_dates = ['Start Date','Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')

mask1 = df['Gender']=='Male'
mask2 = df['Team']=='Marketing'

df[mask1 & mask2].head()
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas   Male 1993-08-06 2023-11-14 12:42:00   97308    6.945
# 21    Matthew   Male 1995-09-05 2023-11-14 02:12:00  100612   13.645
# 26      Craig   Male 2000-02-27 2023-11-14 07:45:00   37598    7.757
# 74     Thomas   Male 1995-06-04 2023-11-14 14:24:00   62096   17.029
# 77    Charles   Male 2004-09-14 2023-11-14 20:13:00  107391    1.260
#
#     Senior Management       Team
# 0                True  Marketing
# 21              False  Marketing
# 26               True  Marketing
# 74              False  Marketing
# 77               True  Marketing

# %%
female = df['Gender']=='Female'
finance = df['Team']=='Finance'

# %%
df[female | finance]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2023-11-14 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-11-14 13:00:00  138705    9.340
# 6         Ruby  Female 1987-08-17 2023-11-14 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2023-11-14 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2023-11-14 06:29:00   95570   18.523
# ..         ...     ...        ...                 ...     ...      ...
# 990      Robin  Female 1987-07-24 2023-11-14 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2023-11-14 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2023-11-14 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2023-11-14 15:53:00   56450   19.040
# 996    Phillip    Male 1984-01-31 2023-11-14 06:30:00   42392   19.675
#
#      Senior Management             Team
# 2                False          Finance
# ...

# %%
male = df['Gender']=='Male'
Cli = df['Team']=='Client Services'
year = df['Start Date']>'2016-06-01'

# %%
df[(male & Cli) | year].head()
# () 소가로까지 해줘야 안전 빵으로 갈 수 있다.
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4       Larry    Male 1998-01-24 2023-11-14 16:47:00  101004    1.389
# 15    Lillian  Female 2016-06-05 2023-11-14 06:09:00   59414    1.256
# 24       John    Male 1992-07-01 2023-11-14 22:08:00   97950   13.873
# 25        NaN    Male 2012-10-08 2023-11-14 01:12:00   37076   18.576
# 28      Terry    Male 1981-11-27 2023-11-14 18:30:00  124008   13.464
#
#     Senior Management             Team
# 4                True  Client Services
# 15              False          Product
# 24              False  Client Services
# 25               True  Client Services
# 28               True  Client Services

# %%
L = df['Team']=='Legal'
P = df['Team']=='Product'
S = df['Team']=='Sales'

df[L | P | S]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2023-11-14 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2023-11-14 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2023-11-14 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2023-11-14 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2023-11-14 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2023-11-14 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2023-11-14 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2023-11-14 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2023-11-14 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2023-11-14 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# ...

# %% [markdown]
# # 성대가 한 방법

# %%
df[df.Team.isna()].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2023-11-14 06:53:00   61933    4.170
# 10     Louise  Female 1980-08-12 2023-11-14 09:01:00   63241   15.132
# 23        NaN    Male 2012-06-14 2023-11-14 16:19:00  125792    5.042
# 32        NaN    Male 1998-08-21 2023-11-14 14:27:00  122340    6.417
# 91      James     NaN 2005-01-26 2023-11-14 23:00:00  128771    8.309
#
#     Senior Management Team
# 1                True  NaN
# 10               True  NaN
# 23               True  NaN
# 32               True  NaN
# 91              False  NaN

# %%
df = pd.read_csv('data/employees.csv', parse_dates = ['Start Date','Last Login Time'])
mask = df.dropna(subset=['Gender'], how='any', axis=0)
mask
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-11-14 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2023-11-14 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2023-11-14 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-11-14 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-11-14 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2023-11-14 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2023-11-14 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2023-11-14 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2023-11-14 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2023-11-14 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m1 = df['Salary'] > 60000
m2 = df['Salary'] < 70000
df[(m1 & m2)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2023-11-14 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2023-11-14 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2023-11-14 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2023-11-14 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2023-11-14 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2023-11-14 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2023-11-14 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2023-11-14 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2023-11-14 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2023-11-14 16:45:00   60500   11.985
#
#     Senior Management                  Team
# 1                True                   NaN
# ...

# %%
df[df['Salary'].between(60000,70000)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2023-11-14 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2023-11-14 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2023-11-14 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2023-11-14 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2023-11-14 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2023-11-14 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2023-11-14 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2023-11-14 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2023-11-14 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2023-11-14 16:45:00   60500   11.985
#
#     Senior Management                  Team
# 1                True                   NaN
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df[df['Bonus %'].between(2,5)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2023-11-14 06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22 2023-11-14 19:18:00   64714    4.934
# 40     Michael    Male 2008-10-10 2023-11-14 11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24 2023-11-14 12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23 2023-11-14 14:01:00   48866    4.271
# ..         ...     ...        ...                 ...     ...      ...
# 943      Wayne    Male 2006-09-08 2023-11-14 11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18 2023-11-14 21:37:00  103050    3.050
# 976     Denise  Female 1992-10-19 2023-11-14 05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10 2023-11-14 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2023-11-14 17:47:00   98874    4.479
#
#     Senior Management          Team
# 1                True           NaN
# 20               True         Legal
# ...

# %%
df[df['Last Login Time'].between('08:30 AM','10:00 PM')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-11-14 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2023-11-14 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-11-14 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-11-14 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2023-11-14 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 993       Tina  Female 1997-05-15 2023-11-14 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2023-11-14 17:47:00   98874    4.479
# 997    Russell    Male 2013-05-20 2023-11-14 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2023-11-14 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2023-11-14 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
df['Team'].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
df['Team'].nunique(dropna=True)
# Out:
# 10

# %%
big = pd.read_csv('data/bigmac.csv', parse_dates=['Date'])

# %%
big
# Out:
#           Date        Country  Price in US Dollars
# 0   2016-01-01      Argentina                 2.39
# 1   2016-01-01      Australia                 3.74
# 2   2016-01-01         Brazil                 3.35
# 3   2016-01-01        Britain                 4.22
# 4   2016-01-01         Canada                 4.14
# ..         ...            ...                  ...
# 647 2010-01-01         Turkey                 3.83
# 648 2010-01-01            UAE                 2.99
# 649 2010-01-01        Ukraine                 1.83
# 650 2010-01-01  United States                 3.58
# 651 2010-01-01        Uruguay                 3.32
#
# [652 rows x 3 columns]

# %%
big.groupby(['Date','Country']).agg({'Price in US Dollars':max}).head(5)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac = pd.read_csv('data/bigmac.csv', parse_dates=['Date'], index_col=['Date','Country'])
bigmac.sort_index(inplace=True)

# %%
bigmac
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
btc = pd.read_csv('data/coin_Bitcoin.csv')
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
btc.set_index('Date').head()
# Out:
#                      SNo     Name Symbol        High         Low        Open  \
# Date
# 2013-04-29 23:59:59    1  Bitcoin    BTC  147.488007  134.000000  134.444000
# 2013-04-30 23:59:59    2  Bitcoin    BTC  146.929993  134.050003  144.000000
# 2013-05-01 23:59:59    3  Bitcoin    BTC  139.889999  107.720001  139.000000
# 2013-05-02 23:59:59    4  Bitcoin    BTC  125.599998   92.281898  116.379997
# 2013-05-03 23:59:59    5  Bitcoin    BTC  108.127998   79.099998  106.250000
#
#                           Close  Volume     Marketcap
# Date
# 2013-04-29 23:59:59  144.539993     0.0  1.603769e+09
# 2013-04-30 23:59:59  139.000000     0.0  1.542813e+09
# 2013-05-01 23:59:59  116.989998     0.0  1.298955e+09
# 2013-05-02 23:59:59  105.209999     0.0  1.168517e+09
# 2013-05-03 23:59:59   97.750000     0.0  1.085995e+09

# %%
btc.High.plot()
# Out:
# <AxesSubplot:>

# %%
btc= pd.read_csv('data/coin_Bitcoin.csv')
btc.High.plot()
# Out:
# <AxesSubplot:>

# %%
countries = pd.read_csv('data/world-happiness-report-2021.csv')
countries
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
countries[['Country name','Healthy life expectancy']]
# Out:
#     Country name  Healthy life expectancy
# 0        Finland                   72.000
# 1        Denmark                   72.700
# 2    Switzerland                   74.400
# 3        Iceland                   73.000
# 4    Netherlands                   72.400
# ..           ...                      ...
# 144      Lesotho                   48.700
# 145     Botswana                   59.269
# 146       Rwanda                   61.400
# 147     Zimbabwe                   56.201
# 148  Afghanistan                   52.493
#
# [149 rows x 2 columns]

# %%
countries.set_index('Country name', inplace=True)
countries['Healthy life expectancy']
# Out:
# Country name
# Finland        72.000
# Denmark        72.700
# Switzerland    74.400
# Iceland        73.000
# Netherlands    72.400
#                 ...
# Lesotho        48.700
# Botswana       59.269
# Rwanda         61.400
# Zimbabwe       56.201
# Afghanistan    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %%
countries['Healthy life expectancy'].sort_values(ascending=False).head().plot()
plt.xticks(rotation=45)
plt.show()

# %%
countries['Ladder score']
# Out:
# Country name
# Finland        7.842
# Denmark        7.620
# Switzerland    7.571
# Iceland        7.554
# Netherlands    7.464
#                ...
# Lesotho        3.512
# Botswana       3.467
# Rwanda         3.415
# Zimbabwe       3.145
# Afghanistan    2.523
# Name: Ladder score, Length: 149, dtype: float64

# %%
house = pd.read_csv('data/kc_house_data.csv')
house.sort_values(by='price', ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# ...

# %%
titanic = pd.read_csv('data/titanic.csv')
titanic['sex'].head()
# Out:
# 0    female
# 1      male
# 2    female
# 3      male
# 4    female
# Name: sex, dtype: object

# %%
df = titanic.head()
df.sex == 'female'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
titanic[titanic['survived']==0]
# Out:
#       pclass  survived                                             name  \
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 7          1         0                           Andrews, Mr. Thomas Jr
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch    ticket     fare    cabin embarked boat  \
# ...

# %%
titanic[titanic['age']=='18']
# Out:
#       pclass  survived                                               name  \
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 198        1         1  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...
# 228        1         0         Penasco y Castellana, Mr. Victor de Satode
# 250        1         1                         Ryerson, Miss. Emily Borie
# 270        1         1     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 289        1         1                                Taussig, Miss. Ruth
# 326        2         0                         Andrew, Mr. Edgardo Samuel
# 331        2         0                           Bailey, Mr. Percy Andrew
# 386        2         0                          Davies, Mr. Charles Henry
# 394        2         0                                Dibden, Mr. William
# 395        2         1                                Doling, Miss. Elsie
# 405        2         0                          Fahlstrom, Mr. Arne Jonas
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
titanic[titanic['pclass']!=1]
# Out:
#       pclass  survived                                   name     sex   age  \
# 323        2         0                    Abelson, Mr. Samuel    male    30
# 324        2         1  Abelson, Mrs. Samuel (Hannah Wizosky)  female    28
# 325        2         0         Aldworth, Mr. Charles Augustus    male    30
# 326        2         0             Andrew, Mr. Edgardo Samuel    male    18
# 327        2         0               Andrew, Mr. Frank Thomas    male    25
# ...      ...       ...                                    ...     ...   ...
# 1304       3         0                   Zabour, Miss. Hileni  female  14.5
# 1305       3         0                  Zabour, Miss. Thamine  female     ?
# 1306       3         0              Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                    Zakarian, Mr. Ortin    male    27
# 1308       3         0                     Zimmerman, Mr. Leo    male    29
#
# ...

# %%
Bestsellers = pd.read_csv('data/bestsellers.csv')
Bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
Bestsellers[Bestsellers['Author']=='Pete Souza']
# Out:
#                             Name      Author  User Rating  Reviews  Price  \
# 244  Obama: An Intimate Portrait  Pete Souza          4.9     3192     22
#
#      Year        Genre
# 244  2017  Non Fiction

# %%
Bestsellers[Bestsellers['Price']<10]
# Out:
#                                                   Name           Author  \
# 0                        10-Day Green Smoothie Cleanse         JJ Smith
# 3                               1984 (Signet Classics)    George Orwell
# 8        A Higher Loyalty: Truth, Lies, and Leadership      James Comey
# 9                            A Man Called Ove: A Novel  Fredrik Backman
# 10                           A Man Called Ove: A Novel  Fredrik Backman
# ..                                                 ...              ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
Bestsellers[(Bestsellers['Price']>=50) & (Bestsellers['Price']<=60)]
# Bestsellers[Bestsellers['Price'].between(50,60)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 159         Harry Potter Paperback Box Set (Books 1-7)       J. K. Rowling
# 346  The Book of Basketball: The NBA According to T...        Bill Simmons
#
#      User Rating  Reviews  Price  Year        Genre
# 151          4.9     5867     54  2016  Non Fiction
# 159          4.8    13471     52  2016      Fiction
# 346          4.7      858     53  2009  Non Fiction

# %%
Bestsellers[(Bestsellers['Author']=='Kristin Hannah') | (Bestsellers['Author']=='Andy Weir') | (Bestsellers['Author']=='Delia Owens')]
# Out:
#                          Name          Author  User Rating  Reviews  Price  \
# 433               The Martian       Andy Weir          4.7    39459      9
# 437  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 438  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 534   Where the Crawdads Sing     Delia Owens          4.8    87841     15
#
#      Year    Genre
# 433  2015  Fiction
# 437  2015  Fiction
# 438  2016  Fiction
# 534  2019  Fiction

# %%
Bestsellers[Bestsellers['Author'].isin(['Kristin Hannah','Andy Weir','Delia Owens'])]
# Out:
#                          Name          Author  User Rating  Reviews  Price  \
# 433               The Martian       Andy Weir          4.7    39459      9
# 437  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 438  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 534   Where the Crawdads Sing     Delia Owens          4.8    87841     15
#
#      Year    Genre
# 433  2015  Fiction
# 437  2015  Fiction
# 438  2016  Fiction
# 534  2019  Fiction

# %%
Bestsellers[(Bestsellers['Genre']=='Non Fiction') & (Bestsellers['User Rating']==4.9)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 174                       Humans of New York : Stories     Brandon Stanton
# 187  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 188  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 189  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 190  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 191  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 192  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 244                        Obama: An Intimate Portrait          Pete Souza
# 431                                 The Magnolia Story         Chip Gaines
# 521                             Unfreedom of the Press       Mark R. Levin
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
B1 = Bestsellers[Bestsellers['User Rating']<4.5]
B1['Author'].value_counts().head().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
hom = pd.read_csv('data/kc_house_data.csv', parse_dates=['date'])
hom
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
timespan = hom['date'].max() - hom['date'].min()
timespan
# 연도와 시간을 보여준다
# Out:
# Timedelta('390 days 00:00:00')

# %%
timespan.days
# Out:
# 390

# %%
y = hom['date'].dt.year
hom_y = y.value_counts()

# %%
labels = ['2014','2015']
plt.pie(
    hom_y,
    labels=labels
)
plt.ylabel('date')
# Out:
# Text(0, 0.5, 'date')

# %% [markdown]
# # 앞으로도 화이팅!
