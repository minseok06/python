# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

titanic = pd.read_csv('data/titanic.csv')

titanic['age'] = titanic['age'].replace(['?'],[None]).astype('float')
titanic['fare'] = titanic['fare'].replace(['?'],[None]).astype('float')
titanic[['age','fare','pclass']]
titanic.groupby('pclass')[['age','fare']].mean().plot(kind='bar')
plt.show()

# %%
df = titanic.groupby(['pclass','sex']).mean()
df.index
# Out:
# MultiIndex([(1, 'female'),
#             (1,   'male'),
#             (2, 'female'),
#             (2,   'male'),
#             (3, 'female'),
#             (3,   'male')],
#            names=['pclass', 'sex'])

# %%
u = [435,454,45,454,554,54,545,45,45,45,45,45,45,454,240,52,40,14,2,52,523,53]
k = [5,435,435,3,53,5,436,6,3,72,643,43,543,643,60,46,436,43,64,6,450,54]
year = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,
        2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]

plt.rc('font', family='Malgun Gothic')
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title('주가 변동 선 그래프')
plt.plot(year, u, label='미국 주가')
plt.plot(year, k, label='한국 주가')
plt.xlabel('Year')
plt.legend()

plt.subplot(1,2,2)
plt.title('주가 변동 막대 그래프')
plt.bar(year, u, label='미국 주가')
plt.bar(year, k, label='한국 주가')
plt.xlabel('Year')
plt.legend()
plt.show()

# %%
pops = pd.read_csv('data/state_pops.csv')
pops
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 1       AL  2010    4785570.0
# 2       AL  2011    4801627.0
# 3       AL  2009    4757938.0
# 4       AL  2013    4833722.0
# ...    ...   ...          ...
# 1267   USA  2013  316128839.0
# 1268   USA  2009  306771529.0
# 1269   USA  2010  309326295.0
# 1270   USA  2011  311582564.0
# 1271   USA  2012  313873685.0
#
# [1272 rows x 3 columns]

# %%
pops.set_index('state')
# Out:
#        year   population
# state
# AL     2012    4817528.0
# AL     2010    4785570.0
# AL     2011    4801627.0
# AL     2009    4757938.0
# AL     2013    4833722.0
# ...     ...          ...
# USA    2013  316128839.0
# USA    2009  306771529.0
# USA    2010  309326295.0
# USA    2011  311582564.0
# USA    2012  313873685.0
#
# [1272 rows x 2 columns]

# %%
pops.set_index('year')
# Out:
#      state   population
# year
# 2012    AL    4817528.0
# 2010    AL    4785570.0
# 2011    AL    4801627.0
# 2009    AL    4757938.0
# 2013    AL    4833722.0
# ...    ...          ...
# 2013   USA  316128839.0
# 2009   USA  306771529.0
# 2010   USA  309326295.0
# 2011   USA  311582564.0
# 2012   USA  313873685.0
#
# [1272 rows x 2 columns]

# %%
pops.set_index(['state','year'])
# Out:
#              population
# state year
# AL    2012    4817528.0
#       2010    4785570.0
#       2011    4801627.0
#       2009    4757938.0
#       2013    4833722.0
# ...                 ...
# USA   2013  316128839.0
#       2009  306771529.0
#       2010  309326295.0
#       2011  311582564.0
#       2012  313873685.0
#
# [1272 rows x 1 columns]

# %%
pops.set_index(['year','state'])
# Out:
#              population
# year state
# 2012 AL       4817528.0
# 2010 AL       4785570.0
# 2011 AL       4801627.0
# 2009 AL       4757938.0
# 2013 AL       4833722.0
# ...                 ...
#      USA    316128839.0
# 2009 USA    306771529.0
# 2010 USA    309326295.0
# 2011 USA    311582564.0
# 2012 USA    313873685.0
#
# [1272 rows x 1 columns]

# %%
pops.set_index(['state','year']).sort_index()
# sort_index()는 가나다라 순으로 정렬해준다.
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.set_index(['state','year'], inplace=True)
# inplace=True는 데이터 원본을 인덱스가 적용된 형태로 고정시키는 효과가 있다.
# 그러나 inplace=True가 없으면 index를 적용하여 나온 내용이 한번 출력되기만 하고
# 원본 데이터에 영향을 주지는 못한다.

# %%
pops.sort_index(ascending=False)
# ascending는 가나다라를 어디 방향으로 할 것인지 정렬해주는 것이다.
# Out:
#             population
# state year
# WY    2013    582658.0
#       2012    576626.0
#       2011    567329.0
#       2010    564222.0
#       2009    559851.0
# ...                ...
# AK    1994    603308.0
#       1993    599434.0
#       1992    588736.0
#       1991    570193.0
#       1990    553290.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index().head(1)
# pops.sort_index(ascending=False).head(1)
# 디폴드는 굉장히 중요하다.
# Out:
#             population
# state year
# AK    1990    553290.0

# %%
pops.sort_index(level=1)
# Out:
#             population
# state year
# AK    1990    553290.0
# AL    1990   4050055.0
# AR    1990   2356586.0
# AZ    1990   3684097.0
# CA    1990  29959515.0
# ...                ...
# VT    2013    626630.0
# WA    2013   6971406.0
# WI    2013   5742713.0
# WV    2013   1854304.0
# WY    2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(level=[1,0],ascending=[False,True])
# Out:
#             population
# state year
# AK    2013    735132.0
# AL    2013   4833722.0
# AR    2013   2959373.0
# AZ    2013   6626624.0
# CA    2013  38332521.0
# ...                ...
# VT    1990    564798.0
# WA    1990   4903043.0
# WI    1990   4904562.0
# WV    1990   1792548.0
# WY    1990    453690.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(level=[0,1],ascending=[False,True])
# Out:
#             population
# state year
# WY    1990    453690.0
#       1991    459260.0
#       1992    466251.0
#       1993    473081.0
#       1994    480283.0
# ...                ...
# AK    2009    698895.0
#       2010    713868.0
#       2011    723375.0
#       2012    730307.0
#       2013    735132.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(inplace=True)

# %%
pops.loc['NM':'TX']
# Out:
#             population
# state year
# NM    1990   1521574.0
#       1991   1555305.0
#       1992   1595442.0
#       1993   1636453.0
#       1994   1682398.0
# ...                ...
# TX    2009  24801761.0
#       2010  25245178.0
#       2011  25640909.0
#       2012  26060796.0
#       2013  26448193.0
#
# [312 rows x 1 columns]

# %%
pops.loc['MT',1992]
# Out:
# population    825770.0
# Name: (MT, 1992), dtype: float64

# %%
pops.loc[['AK']][2:6]
# Out:
#             population
# state year
# AK    1992    588736.0
#       1993    599434.0
#       1994    603308.0
#       1995    604412.0

# %%
pops.loc[('AK',2011):('AL',1993)]
# Out:
#             population
# state year
# AK    2011    723375.0
#       2012    730307.0
#       2013    735132.0
# AL    1990   4050055.0
#       1991   4099156.0
#       1992   4154014.0
#       1993   4214202.0

# %%
titanic = pd.read_csv('data/titanic.csv')
titanic.loc[(19,'name')]
# Out:
# 'Beattie, Mr. Thomson'

# %%
pops
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.loc[('PR',1990)]
# Out:
# population   NaN
# Name: (PR, 1990), dtype: float64

# %%
pops.groupby('state').min().tail()
# Out:
#          year  population
# state
# VT     1990.0    564798.0
# WA     1990.0   4903043.0
# WI     1990.0   4904562.0
# WV     1990.0   1792548.0
# WY     1990.0    453690.0

# %%
pops = pd.read_csv('data/state_pops.csv')
pops['year']=pops['year'].replace(["?"],[None]).astype("float")
pops.set_index(['year','state']).loc[1990].tail()
# Out:
#         population
# state
# WV       1792548.0
# WI       4904562.0
# WY        453690.0
# PR             NaN
# USA    249622814.0

# %%
'EVERLAND'+' 가고싶다.'
# Out:
# 'EVERLAND 가고싶다.'

# %%
pops
# Out:
#               population
# state year
# AK    1990.0    553290.0
#       1991.0    570193.0
#       1992.0    588736.0
#       1993.0    599434.0
#       1994.0    603308.0
# ...                  ...
# WY    2009.0    559851.0
#       2010.0    564222.0
#       2011.0    567329.0
#       2012.0    576626.0
#       2013.0    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.loc[:,1990, :].head()
# Out:
#        population
# state
# AK       553290.0
# AL      4050055.0
# AR      2356586.0
# AZ      3684097.0
# CA     29959515.0

# %%
pops.loc[:,1990:1991, :]
# Out:
#               population
# state year
# AK    1990.0    553290.0
#       1991.0    570193.0
# AL    1990.0   4050055.0
#       1991.0   4099156.0
# AR    1990.0   2356586.0
# ...                  ...
# WI    1991.0   4964343.0
# WV    1990.0   1792548.0
#       1991.0   1798735.0
# WY    1990.0    453690.0
#       1991.0    459260.0
#
# [106 rows x 1 columns]

# %%
pops.loc[:,[1990,1991], :]
# Out:
#               population
# state year
# AK    1990.0    553290.0
#       1991.0    570193.0
# AL    1990.0   4050055.0
#       1991.0   4099156.0
# AR    1990.0   2356586.0
# ...                  ...
# WI    1991.0   4964343.0
# WV    1990.0   1792548.0
#       1991.0   1798735.0
# WY    1990.0    453690.0
#       1991.0    459260.0
#
# [106 rows x 1 columns]

# %%
'abcdefglijklmnopqrstuvwxyz'
# Out:
# 'abcdefglijklmnopqrstuvwxyz'

# %%
pops.loc[:,[2013],:].head()
# Out:
#               population
# state year
# AK    2013.0    735132.0
# AL    2013.0   4833722.0
# AR    2013.0   2959373.0
# AZ    2013.0   6626624.0
# CA    2013.0  38332521.0

# %%
pops.set_index('population').loc[:]
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
pops[pops['population']%2==0]
# Out:
#               population
# state year
# AK    1990.0    553290.0
#       1992.0    588736.0
#       1993.0    599434.0
#       1994.0    603308.0
#       1995.0    604412.0
# ...                  ...
# WY    2004.0    509106.0
#       2007.0    534876.0
#       2010.0    564222.0
#       2012.0    576626.0
#       2013.0    582658.0
#
# [645 rows x 1 columns]

# %%
n = input('이름을 입력하세요 : ')
print('----------------------------')
print('{} 바보 멍청이 다이아수저'.format(n))
# Out:
# 이름을 입력하세요 : 너는
# ----------------------------
# 너는 바보 멍청이 다이아수저

# %%
titanic = pd.read_csv('data/titanic.csv')
titanic['age'] = titanic['age'].replace(['?'],[None]).astype('float')
titanic['fare'] = titanic['fare'].replace(['?'],[None]).astype('float')

titanic.groupby('sex').agg({'age':['min','max','mean'],'fare':['min','max','mean'],
                           'survived':['mean']})
# Out:
#            age                   fare                       survived
#            min   max       mean   min       max       mean      mean
# sex
# female  0.1667  76.0  28.687071  6.75  512.3292  46.198097  0.727468
# male    0.3333  80.0  30.585233  0.00  512.3292  26.154601  0.190985

# %%
titanic.groupby(['pclass','sex'])['age'].mean().plot(kind='bar')
plt.show()

# %%
titanic.groupby(['pclass','sex'])['age'].mean()
# Out:
# pclass  sex
# 1       female    37.037594
#         male      41.029250
# 2       female    27.499191
#         male      30.815401
# 3       female    22.185307
#         male      25.962273
# Name: age, dtype: float64

# %%
titanic.groupby(['pclass','sex'])['age'].mean().unstack()
# unstack()을 사용하면 더 보기 좋아진다.
# Out:
# sex        female       male
# pclass
# 1       37.037594  41.029250
# 2       27.499191  30.815401
# 3       22.185307  25.962273

# %%
titanic.groupby(['pclass','sex'])['age'].mean().unstack().plot(kind='bar')
plt.show()

# %%
titanic.groupby(['sex','pclass'])['age'].mean().unstack().plot(kind='bar')
plt.show()
