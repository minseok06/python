# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s = pd.read_csv("data/Salaries.csv", low_memory=False)
s.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
s["BasePay"]=pd.to_numeric(s["BasePay"], errors="coerce").fillna(0)
s["OvertimePay"]=pd.to_numeric(s["OvertimePay"], errors="coerce").fillna(0)
s["OtherPay"]=pd.to_numeric(s["OtherPay"], errors="coerce").fillna(0)
df = s[["EmployeeName", "BasePay", "OvertimePay", "OtherPay"]]
df.set_index("EmployeeName", inplace=True)
df.head(10).plot(kind="bar", stacked=True)
# Out:
# <AxesSubplot:xlabel='EmployeeName'>

# %% [markdown]
# ### 만약 숫자로 변경할 수 없는 데이터라면 기존 데이터를 지우고
# ### NaN으로 설정하여 반환하는 메소드 : errors="coerce"
# #### fillna(0) : NaN으로 기록된 부분을 숫자 0으로 반환하라는 메소드

# %%
a = s[["EmployeeName","BasePay","OvertimePay","OtherPay"]].head(10).plot(kind="bar")
plt.xlabel("EmployeeName")
# Out:
# Text(0.5, 0, 'EmployeeName')

# %% [markdown]
# Sorting => 정렬하다.
# sort_values => 값의 순서대로 정렬.

# %%
b = s["BasePay"].sort_values(ascending=False).head()
b.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### ascending : 오름차순, descending: 내림차순
# - ascending = True, False

# %%
df = s[["EmployeeName", "BasePay", "OvertimePay", "OtherPay"]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   EmployeeName  148654 non-null  object
#  1   BasePay       148654 non-null  float64
#  2   OvertimePay   148654 non-null  float64
#  3   OtherPay      148654 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 4.5+ MB

# %% [markdown]
# info()라는 메소드는 데이터 안에 어떤 내용이 들어가 있는지를 확인하도록 해준다.

# %%
df.head()
# Out:
#         EmployeeName    BasePay  OvertimePay   OtherPay
# 0     NATHANIEL FORD  167411.18         0.00  400184.25
# 1       GARY JIMENEZ  155966.02    245131.88  137811.38
# 2     ALBERT PARDINI  212739.13    106088.18   16452.60
# 3  CHRISTOPHER CHONG   77916.00     56120.71  198306.90
# 4    PATRICK GARDNER  134401.60      9737.00  182234.59

# %%
df.sort_values("OvertimePay", ascending=False).head().plot(kind="bar", stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.sort_values("OvertimePay", ascending=False).head().plot(kind="barh", stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.sort_values("BasePay", ascending=False).head().plot(kind="hist", stacked=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[["EmployeeName", "BasePay", "OvertimePay", "OtherPay"]].plot(kind = "hist", bins=100)
# 빈스는 데이터 크기 조절
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'BasePay'}>,
#         <AxesSubplot:title={'center':'OvertimePay'}>],
#        [<AxesSubplot:title={'center':'OtherPay'}>, <AxesSubplot:>]],
#       dtype=object)
